# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe(include = "all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
df.species.value_counts()
#          (OR)
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#Applying function on all columns
df.apply(np.max)
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %%
#sorting by index
df.sort_index(ascending = False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 149           5.9          3.0           5.1          1.8  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 4             5.0          3.6           1.4          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 0             5.1          3.5           1.4          0.2     setosa
#
# [150 rows x 5 columns]

# %%
#sorting by values
df.sort_values(by = "sepal_length").head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 13           4.3          3.0           1.1          0.1  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 42           4.4          3.2           1.3          0.2  setosa
# 38           4.4          3.0           1.3          0.2  setosa
# 41           4.5          2.3           1.3          0.3  setosa

# %% [markdown]
# #Indexing and Slicing

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df[0:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#creating one column dataframe by using existing dataframe
new_df = df["sepal_length"]
new_df.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
type(new_df)
# Out:
# pandas.core.series.Series

# %%
#creating multiple column dataframe by using existing dataframe
new_df = df[["sepal_length","species"]] #to take multiple clumn we have to keep in list
new_df.head()
# Out:
#    sepal_length species
# 0           5.1  setosa
# 1           4.9  setosa
# 2           4.7  setosa
# 3           4.6  setosa
# 4           5.0  setosa

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#we can create a dataframe with single column
new_df = df[["sepal_length"]]
new_df.head()
# Out:
#    sepal_length
# 0           5.1
# 1           4.9
# 2           4.7
# 3           4.6
# 4           5.0

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# iloc() vs loc()
# iloc() => position based indexing [int]
# loc() => Label based indexing [string]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Integer Location Based Index

# %%
n#syntax ->df.iloc[default_row_index , default_column_index]
df.iloc[2]
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
df.iloc[1,2]
# Out:
# np.float64(1.4)

# %%
df.iloc[3,:]
# Out:
# sepal_length       4.6
# sepal_width        3.1
# petal_length       1.5
# petal_width        0.2
# species         setosa
# Name: 3, dtype: object

# %%
df.iloc[[1,2,5]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df.iloc[[1,2,5],[1,2,3]]
# Out:
#    sepal_width  petal_length  petal_width
# 1          3.0           1.4          0.2
# 2          3.2           1.3          0.2
# 5          3.9           1.7          0.4

# %%
df.iloc[3:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iloc[:,4]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# Label Based Index

# %%
#df.loc[row label , column label]
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.loc[2]
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
df.loc[2,"species"]
# Out:
# 'setosa'

# %%
df.loc[3,:]
# Out:
# sepal_length       4.6
# sepal_width        3.1
# petal_length       1.5
# petal_width        0.2
# species         setosa
# Name: 3, dtype: object

# %%
df.loc[[1,3,4]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.loc[[1,3,4],"sepal_width":"species"]
# Out:
#    sepal_width  petal_length  petal_width species
# 1          3.0           1.4          0.2  setosa
# 3          3.1           1.5          0.2  setosa
# 4          3.6           1.4          0.2  setosa

# %%
df.loc[[1,3,4],["sepal_width","species"]]
# Out:
#    sepal_width species
# 1          3.0  setosa
# 3          3.1  setosa
# 4          3.6  setosa
